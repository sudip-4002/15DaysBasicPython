# %% [markdown]
# <a href="https://colab.research.google.com/github/sudip-4002/15DaysBasicPython/blob/main/day05_Nested_conditions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Basic Nested If Example

age = 20

if age >= 18:
    print("You are eligible to vote")

    if age >= 21:
        print("You can apply for higher responsibilities")
# Out:
# You are eligible to vote

# %%
# 2. ID Verification System

age = 19
id_card = True

if age >= 18:
    print("Age verified")

    if id_card == True:
        print("Entry allowed")
    else:
        print("ID card required")
else:
    print("Not eligible")
# Out:
# Age verified
# Entry allowed

# %%
# 3. Student Result System

marks = 85

if marks >= 50:
    print("Result: Pass")

    if marks >= 90:
        print("Grade: A")
    elif marks >= 75:
        print("Grade: B")
    else:
        print("Grade: C")
else:
    print("Result: Fail")
# Out:
# Result: Pass
# Grade: B

# %%
# 4. ATM System Example

account_balance = 5000
withdraw_amount = 2000
pin_verified = True

if pin_verified:
    print("PIN Verified")

    if withdraw_amount <= account_balance:
        account_balance = account_balance - withdraw_amount
        print("Transaction Successful")
        print("Remaining Balance:", account_balance)
    else:
        print("Insufficient Balance")
else:
    print("Incorrect PIN")
# Out:
# PIN Verified
# Transaction Successful
# Remaining Balance: 3000

# %%
# 5. Login System with Role Check

username = "sudip"
password = "1234"
user_role = "sudip"

if username == "sudip" and password == "1234":
    print("Login Successful")

    if user_role == "sudip":
        print("Welcome sudip Dashboard")
    else:
        print("Welcome User Dashboard")
else:
    print("Login Failed")
# Out:
# Login Successful
# Welcome sudip Dashboard
