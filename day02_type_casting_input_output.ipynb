# %%
# Input from user
name = input("Enter your name: ")
age = input("Enter your age: ")

# Output to user
print("\nHello,", name)
print("You are", age, "years old")
# Out:
# Enter your name: sudip
# Enter your age: 22
#
# Hello, sudip
# You are 22 years old

# %%
# Type casting example
age = input("Enter your age: ")  # input is string
print("Data type of age:", type(age))

# Convert string to integer
age_int = int(age)
print("Data type after conversion to int:", type(age_int))

# Convert integer to float
age_float = float(age_int)
print("Data type after conversion to float:", type(age_float))
# Out:
# Enter your age: 22
# Data type of age: <class 'str'>
# Data type after conversion to int: <class 'int'>
# Data type after conversion to float: <class 'float'>

# %% [markdown]
# Multiple type casting

# %%
# Multiple type casting
num1 = input("Enter first number: ")
num2 = input("Enter second number: ")

# Convert to float for calculation
num1 = float(num1)
num2 = float(num2)

# Sum of two numbers
total = num1 + num2
print("\nSum of", num1, "and", num2, "is:", total)
# Out:
# Enter first number: 2
# Enter second number: 4
#
# Sum of 2.0 and 4.0 is: 6.0

# %%
# Clone your repo (replace with your repo URL)
# !git clone https://github.com/sudip-4002/15DaysBasicPython.git
# Move into the repo folder
# Out:
# Cloning into '15DaysBasicPython'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 6 (delta 0), reused 3 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (6/6), done.

# %%
# Move into the repo folder
# %cd 15DaysBasicPython
# Out:
# /content/15DaysBasicPython

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls "/content/drive/MyDrive/Colab Notebooks/"
# Out:
# 'Copy of pandas 3 12'				  Seaborn.jpynd
# 'Copy of Seaborn.jpynd'				  Untitled
#  day01_variables.ipynb				  Untitled0.ipynb
#  day01_variables.ipynd				  Untitled11.ipynb
# 'day02_type casting input output . ipynb.ipynb'   Untitled6.ipynb
#  Matplotlib.ipynb				  Untitled9.ipynb
# 'pandas 3 12'

# %%
# !mv "/content/drive/MyDrive/Colab Notebooks/day02_type casting input output . ipynb.ipynb" "/content/drive/MyDrive/Colab Notebooks/day02_type_casting_input_output.ipynb"

# %%
# !ls "/content/drive/MyDrive/Colab Notebooks/"
# Out:
# 'Copy of pandas 3 12'			 Matplotlib.ipynb   Untitled11.ipynb
# 'Copy of Seaborn.jpynd'			'pandas 3 12'	    Untitled6.ipynb
#  day01_variables.ipynb			 Seaborn.jpynd	    Untitled9.ipynb
#  day01_variables.ipynd			 Untitled
#  day02_type_casting_input_output.ipynb	 Untitled0.ipynb

# %%
# %pwd
# Out:
# '/content/15DaysBasicPython'

# %%
# !ls
# Out:
# day01_variables.ipynb  README.md

# %%
# !cp "/content/drive/MyDrive/Colab Notebooks/day02_type casting input output . ipynb.ipynb"
# Out:
# cp: missing destination file operand after '/content/drive/MyDrive/Colab Notebooks/day02_type casting input output . ipynb.ipynb'
# Try 'cp --help' for more information.
